# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data

# %%
london_bikes = pd.read_csv("./data/london_bikes.csv")
london_bikes.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
titanic = pd.read_csv("./data/titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
energy = pd.read_csv("./data/US_energy_sector.csv")
energy.head()
# Out:
#    Unnamed: 0   Month          All         Coal  Natural gas    Nuclear  \
# 0           0  Sep-23  358136.2599  60005.67580  164466.3568  65559.710
# 1           1  Aug-23  423934.2574  78184.50094  199993.0422  69744.023
# 2           2  Jul-23  425611.3284  78909.85665  200506.7592  69887.588
# 3           3  Jun-23  356672.3849  57697.75156  161692.7028  64965.076
# 4           4  May-23  327532.6236  43852.22406  137795.2922  61472.883
#
#    Hydroelectric         Wind        Solar
# 0    16496.04043  28193.29153  22192.58066
# 1    21145.86624  28504.16694  25350.26673
# 2    21237.80849  27867.90946  26538.55725
# 3    19470.63281  27505.93547  25034.48613
# 4    27479.13413  32018.24592  24462.37510

# %% [markdown]
# # Scatter plot

# %% [markdown]
# # Pie vs. Bar plot comparison

# %% [markdown]
# # Line/Area plot
