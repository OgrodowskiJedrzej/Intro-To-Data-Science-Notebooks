# %% [markdown]
# This notebook is for live coding session.
#
# Chart makeover for sales analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('data/data.csv')

plt.figure(figsize=(10, 6))

years = data['Year'].unique()
months = data['Month'].unique()

for year in years:
    yearlyData = data[data['Year'] == year]
    plt.plot(months, yearlyData['Sales'], marker='o', label=f'Sales {year}')

plt.title('Monthly Sales Comparison (2020-2023)', fontsize=14)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Sales ($)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)  
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Can we do this better to show story in this chart?
#
# If we consider Data Science application in Buisness, our charts should be as simple as possible to make work easier for people who don't do it every day.
#
# Now we will:
# - shorten months labels
# - line colors
# - delete grid
# - delete xlabel
# - change colors of labels and ticks
# - make title nicer

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('data/data.csv')

plt.figure(figsize=(10, 6))

years = data['Year'].unique()
months = data['Month'].unique()

for year in years:
    yearlyData = data[data['Year'] == year]
    plt.plot(months, yearlyData['Sales'], marker='o', label=f'Sales {year}')

plt.title('Monthly Sales Comparison (2020-2023)', fontsize=14)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Sales ($)', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()

plt.tight_layout()
plt.show()
