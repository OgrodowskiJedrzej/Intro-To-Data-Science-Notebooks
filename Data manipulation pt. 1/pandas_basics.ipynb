# %% [markdown]
# <center>
#     <h2>
#         Best knowledge source 😍 -
#         <a href="https://wesmckinney.com/book/pandas-basics">here</a>
#     </h2>
# </center>
#
# ---

# %% [markdown]
# # Library import

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# # Reading files
#
# Source: <a href="https://www.kaggle.com/datasets/brendan45774/test-file">Brenda N - Kaggle</a>

# %%
data = pd.read_csv("./data/titanic.csv")
data.head() # tail or sample
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# # Reading data from DataFrame

# %% [markdown]
# #### `.loc`

# %%
data.loc[5]
# data.loc[5:10]
# Out:
# PassengerId                           897
# Survived                                0
# Pclass                                  3
# Name           Svensson, Mr. Johan Cervin
# Sex                                  male
# Age                                  14.0
# SibSp                                   0
# Parch                                   0
# Ticket                               7538
# Fare                                9.225
# Cabin                                 NaN
# Embarked                                S
# Name: 5, dtype: object

# %%
data.loc[5:10, ["Name", "Age"]]
# Out:
#                                          Name   Age
# 5                  Svensson, Mr. Johan Cervin  14.0
# 6                        Connolly, Miss. Kate  30.0
# 7                Caldwell, Mr. Albert Francis  26.0
# 8   Abrahim, Mrs. Joseph (Sophie Halaut Easu)  18.0
# 9                     Davies, Mr. John Samuel  21.0
# 10                           Ilieff, Mr. Ylio   NaN

# %% [markdown]
# #### `.iloc`

# %%
data.iloc[5]
# Out:
# PassengerId                           897
# Survived                                0
# Pclass                                  3
# Name           Svensson, Mr. Johan Cervin
# Sex                                  male
# Age                                  14.0
# SibSp                                   0
# Parch                                   0
# Ticket                               7538
# Fare                                9.225
# Cabin                                 NaN
# Embarked                                S
# Name: 5, dtype: object

# %%
data.iloc[:, 3:6]
# Out:
#                                              Name     Sex   Age
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5
# 416                           Ware, Mr. Frederick    male   NaN
# 417                      Peter, Master. Michael J    male   NaN
#
# [418 rows x 3 columns]

# %% [markdown]
# # Basic informatin about dataset

# %% [markdown]
# #### `.info`

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# #### `.describe`

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
data['Age'].mean()
# Out:
# 30.272590361445783

# %% [markdown]
# #### `.unique`

# %%
data['Pclass'].unique()
# Out:
# array([3, 2, 1], dtype=int64)

# %% [markdown]
# # Droping and filling empty cells

# %% [markdown]
# ### `.dropna`

# %%
data.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 41           933         0       1
# 299         1191         0       3
# 278         1170         0       2
# 266         1158         0       1
# 309         1201         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 41                  Franklin, Mr. Thomas Parham    male   NaN      0      0
# 299                         Johansson, Mr. Nils    male  29.0      0      0
# 278                        Ware, Mr. John James    male  30.0      1      0
# 266       Chisholm, Mr. Roderick Robert Crispin    male   NaN      0      0
# 309  Hansen, Mrs. Claus Peter (Jennie L Howard)  female  45.0      1      0
#
#        Ticket     Fare Cabin Embarked
# 41     113778  26.5500   D34        S
# 299    347467   7.8542   NaN        S
# 278  CA 31352  21.0000   NaN        S
# 266    112051   0.0000   NaN        S
# 309    350026  14.1083   NaN        S

# %%
data_copy = data.dropna(subset=["Age"])
# data_copy = data.dropna(subset=["Age", "Fare"])
data_copy
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 409         1301         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
# 415         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 3                                   Wirz, Mr. Albert    male  27.0      0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                               ...     ...   ...    ...
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 414                     Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                     Saether, Mr. Simon Sivertsen    male  38.5      0
#
#      Parch              Ticket      Fare Cabin Embarked
# 0        0              330911    7.8292   NaN        Q
# 1        0              363272    7.0000   NaN        S
# 2        0              240276    9.6875   NaN        Q
# 3        0              315154    8.6625   NaN        S
# 4        1             3101298   12.2875   NaN        S
# ..     ...                 ...       ...   ...      ...
# 409      1  SOTON/O.Q. 3101315   13.7750   NaN        S
# 411      0               19928   90.0000   C78        Q
# 412      0              347086    7.7750   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
#
# [331 rows x 12 columns]

# %% [markdown]
# ### `.dropna` inplace

# %%
data.dropna(subset=["Age"], inplace=True)
len(data)
# Out:
# 332

# %% [markdown]
# ### `.fillna`

# %%
data['Cabin'].fillna("not known", inplace=True)
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare      Cabin Embarked
# 0   330911   7.8292  not known        Q
# 1   363272   7.0000  not known        S
# 2   240276   9.6875  not known        Q
# 3   315154   8.6625  not known        S
# 4  3101298  12.2875  not known        S

# %% [markdown]
# # Droping rows and columns

# %% [markdown]
# #### Drop rows

# %%
data.drop(0).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S
# 5     7538   9.2250   NaN        S

# %% [markdown]
# #### Drop columns

# %%
data.drop("PassengerId", axis=1).head()
# Out:
#    Survived  Pclass                                          Name     Sex  \
# 0         0       3                              Kelly, Mr. James    male
# 1         1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2         0       2                     Myles, Mr. Thomas Francis    male
# 3         0       3                              Wirz, Mr. Albert    male
# 4         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# # Filtering

# %%
data[data['Age'] > 30].head()
# Out:
#     PassengerId  Survived  Pclass                              Name     Sex  \
# 0           892         0       3                  Kelly, Mr. James    male
# 1           893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2           894         0       2         Myles, Mr. Thomas Francis    male
# 11          903         0       1        Jones, Mr. Charles Cresson    male
# 13          905         0       2              Howard, Mr. Benjamin    male
#
#      Age  SibSp  Parch  Ticket     Fare      Cabin Embarked
# 0   34.5      0      0  330911   7.8292  not known        Q
# 1   47.0      1      0  363272   7.0000  not known        S
# 2   62.0      0      0  240276   9.6875  not known        Q
# 11  46.0      0      0     694  26.0000  not known        S
# 13  63.0      1      0   24065  26.0000  not known        S

# %%
data[data["Sex"] == "female"].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1           893         1       3
# 4           896         1       3
# 6           898         1       3
# 8           900         1       3
# 12          904         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 6                            Connolly, Miss. Kate  female  30.0      0      0
# 8       Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0      0
# 12  Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1      0
#
#      Ticket     Fare      Cabin Embarked
# 1    363272   7.0000  not known        S
# 4   3101298  12.2875  not known        S
# 6    330972   7.6292  not known        Q
# 8      2657   7.2292  not known        C
# 12    21228  82.2667        B45        S

# %% [markdown]
# #### Filtering with multiple conditions

# %%
data_copy = data[(data['Age'] > 30) & (data['Sex'] == "female")]
# data_copy = data[(data['Age'] > 30) | (data['Sex'] == "female")]
print(len(data_copy))
data_copy.head()
# Out:
# 50
#     PassengerId  Survived  Pclass  \
# 1           893         1       3
# 14          906         1       1
# 19          911         1       3
# 24          916         1       1
# 32          924         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 19              Assaf Khalil, Mrs. Mariana (Miriam")"  female  45.0      0
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 32           Dean, Mrs. Bertram (Eva Georgetta Light)  female  33.0      1
#
#     Parch       Ticket     Fare            Cabin Embarked
# 1       0       363272    7.000        not known        S
# 14      0  W.E.P. 5734   61.175              E31        S
# 19      0         2696    7.225        not known        C
# 24      3     PC 17608  262.375  B57 B59 B63 B66        C
# 32      2    C.A. 2315   20.575        not known        S

# %% [markdown]
# #### `.isnull()` and `.notnull()`

# %%
data = pd.read_csv("./data/titanic.csv")

# data[data['Age'].notnull()].head()
data[data['Age'].isnull()].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 10          902         0       3
# 22          914         1       1
# 29          921         0       3
# 33          925         1       3
# 36          928         1       3
#
#                                                  Name     Sex  Age  SibSp  \
# 10                                   Ilieff, Mr. Ylio    male  NaN      0
# 22               Flegenheim, Mrs. Alfred (Antoinette)  female  NaN      0
# 29                                  Samaan, Mr. Elias    male  NaN      2
# 33  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female  NaN      1
# 36                                Roth, Miss. Sarah A  female  NaN      0
#
#     Parch      Ticket     Fare Cabin Embarked
# 10      0      349220   7.8958   NaN        S
# 22      0    PC 17598  31.6833   NaN        S
# 29      0        2662  21.6792   NaN        C
# 33      2  W./C. 6607  23.4500   NaN        S
# 36      0      342712   8.0500   NaN        S

# %% [markdown]
# #### `.isin`

# %%
data[data['Pclass'].isin([1, 2])].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 2           894         0       2
# 7           899         0       2
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 7                    Caldwell, Mr. Albert Francis    male  26.0      1      1
# 11                     Jones, Mr. Charles Cresson    male  46.0      0      0
# 12  Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1      0
# 13                           Howard, Mr. Benjamin    male  63.0      1      0
#
#     Ticket     Fare Cabin Embarked
# 2   240276   9.6875   NaN        Q
# 7   248738  29.0000   NaN        S
# 11     694  26.0000   NaN        S
# 12   21228  82.2667   B45        S
# 13   24065  26.0000   NaN        S

# %% [markdown]
# # Sorting

# %% [markdown]
# #### `.sort_values`

# %%
data.sort_values("Age")
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 201         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 281         1173         0       3           Peacock, Master. Alfred Edward
# 307         1199         0       3                Aks, Master. Philip Frank
# 250         1142         1       2                    West, Miss. Barbara J
# ..           ...       ...     ...                                      ...
# 408         1300         1       3          Riordan, Miss. Johanna Hannah""
# 410         1302         1       3                   Naughton, Miss. Hannah
# 413         1305         0       3                       Spector, Mr. Woolf
# 416         1308         0       3                      Ware, Mr. Frederick
# 417         1309         0       3                 Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# 354  female  0.17      1      2           C.A. 2315  20.5750   NaN        S
# 201    male  0.33      0      2              347080  14.4000   NaN        S
# 281    male  0.75      1      1  SOTON/O.Q. 3101315  13.7750   NaN        S
# 307    male  0.83      0      1              392091   9.3500   NaN        S
# 250  female  0.92      1      2          C.A. 34651  27.7500   NaN        S
# ..      ...   ...    ...    ...                 ...      ...   ...      ...
# 408  female   NaN      0      0              334915   7.7208   NaN        Q
# 410  female   NaN      0      0              365237   7.7500   NaN        Q
# 413    male   NaN      0      0           A.5. 3236   8.0500   NaN        S
# 416    male   NaN      0      0              359309   8.0500   NaN        S
# 417    male   NaN      1      1                2668  22.3583   NaN        C
#
# [418 rows x 12 columns]

# %% [markdown]
# #### `.sort_index`

# %%
data.sort_index()
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %% [markdown]
# #### `.reset_index`

# %%
data.sort_values("Age", inplace=True)
data.reset_index(drop=True, inplace=True)
data.head()
# Out:
#    PassengerId  Survived  Pclass                                     Name  \
# 0         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 1         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 2         1173         0       3           Peacock, Master. Alfred Edward
# 3         1199         0       3                Aks, Master. Philip Frank
# 4         1142         1       2                    West, Miss. Barbara J
#
#       Sex   Age  SibSp  Parch              Ticket    Fare Cabin Embarked
# 0  female  0.17      1      2           C.A. 2315  20.575   NaN        S
# 1    male  0.33      0      2              347080  14.400   NaN        S
# 2    male  0.75      1      1  SOTON/O.Q. 3101315  13.775   NaN        S
# 3    male  0.83      0      1              392091   9.350   NaN        S
# 4  female  0.92      1      2          C.A. 34651  27.750   NaN        S

# %% [markdown]
# # Aggregation

# %%
data = pd.read_csv("./data/titanic.csv")

# %% [markdown]
# #### `.mean`, `.count`, `.sum`, etc.

# %%
data[["Sex", "Age"]].groupby(["Sex"]).mean()
# Out:
#               Age
# Sex
# female  30.272362
# male    30.272732

# %%
data[["Sex", "PassengerId"]].groupby("Sex").count()
# Out:
#         PassengerId
# Sex
# female          152
# male            266

# %%
data[["Sex", "Fare"]].groupby("Sex").sum()
# Out:
#              Fare
# Sex
# female  7561.6502
# male    7294.8874

# %% [markdown]
# #### `.agg`

# %%
data[["Sex", "Fare"]].groupby("Sex").agg(["sum", "mean", "count"])
# Out:
#              Fare
#               sum       mean count
# Sex
# female  7561.6502  49.747699   152
# male    7294.8874  27.527877   265
